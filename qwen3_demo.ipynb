# %%
# !pip install ollama

# %%
import ollama

# %%
# !ollama --version
# Out:
# ollama version is 0.6.6

# %%
# !ollama pull qwen3:8b
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest
# pulling a3de86cd1c13: 100% ▕██████████████████▏ 5.2 GB
# pulling eb4402837c78: 100% ▕██████████████████▏ 1.5 KB
# pulling d18a5cc71b84: 100% ▕██████████████████▏  11 KB
# pulling cff3f395ef37: 100% ▕██████████████████▏  120 B
# pulling 05a61d37b084: 100% ▕██████████████████▏  487 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# ## Accessing Qwen3 via Python

# %%
import ollama
response = ollama.chat(
    model="qwen3:8b",
    messages=[
        {"role": "user", "content": "Summarize the theory of evolution. /think"}
    ]
)
print(response["message"]["content"])
# Out:
# <think>
# Okay, the user wants me to summarize the theory of evolution. Let me start by recalling the key points. First, I need to mention Charles Darwin and his role in developing the theory. Then, the main idea is that all species undergo changes over time through natural selection. Wait, I should explain natural selection properly. It's about organisms with advantageous traits surviving and passing those traits to offspring.
#
# I should also include the concept of common descent, meaning all life shares a common ancestor. Maybe mention genetic variation and mutations as sources of variation. Oh, and the evidence supporting evolution, like fossil records, comparative anatomy, and molecular biology. Also, clarify that evolution isn't about progress but gradual change. Let me make sure I'm not missing any major components. Don't forget to note that it's a unifying theory in biology. Let me structure this clearly, starting with the basic premise, then the mechanisms, evidence, and implications. Keep it concise but comprehensive. Avoid jargon where possible. Alright, that should cover the main points without getting too detailed.
# </think>
#
# The **theory of evolution** explains how all living organisms have changed over time through processes that lead to the diversity of life on Earth. Here's a concise summary:
#
# 1. **Core Idea**: Species undergo gradual changes over generations, leading to new traits and, eventually, new species.
# 2. **Mechanism**: **Natural Selection** is the primary driver. Individuals with advantageous traits (due to genetic variation) are more likely to survive and reproduce, passing these traits to offspring.
# 3. **Common Descent**: All life shares a common ancestor, with species branching over time through divergence (e.g., humans and chimpanzees share a common primate ancestor).
# 4. **Evidence**:
#    - **Fossil Record**: Shows transitional forms and changes over time.
#    - **Comparative Anatomy**: Homologous structures (e.g., limbs in vertebrates) suggest shared ancestry.
#    - **Molecular Biology**: DNA and protein similarities across species support evolutionary relationships.
#    - **Biogeography**: Species distributions reflect evolutionary history (e.g., Galápagos finches).
# 5. **Key Concepts**:
#    - **Genetic Variation**: Mutations and recombination create diversity.
#    - **Adaptation**: Traits evolve to improve survival and reproduction in specific environments.
#    - **No "Goal"**: Evolution is not directed toward "progress" but results from natural processes.
#
# Evolution is a unifying framework in biology, explaining the diversity and interconnectedness of life.

# %% [markdown]
# # Building a Reasoning Demo With Hybrid Thinking

# %% [markdown]
# ## Tab 1: Hybrid Reasoning Demo With /think and /no_think

# %%
import gradio as gr
import subprocess

def reasoning_qwen3(prompt, mode):
    prompt_with_mode = f"{prompt} /{mode}"
    result = subprocess.run(
        ["ollama", "run", "qwen3:8b"],
        input=prompt_with_mode.encode(),
        stdout=subprocess.PIPE
    )
    return result.stdout.decode()

reasoning_ui = gr.Interface(
    fn=reasoning_qwen3,
    inputs=[
        gr.Textbox(label="Enter your prompt"),
        gr.Radio(["think", "no_think"], label="Reasoning Mode", value="think")
    ],
    outputs="text",
    title="Qwen3 Reasoning Mode Demo",
    description="Switch between /think and /no_think to control response depth."
)

# %% [markdown]
# ## Tab 2: Multilingual Application Demo

# %%
import gradio as gr
import subprocess

def multilingual_qwen3(prompt, lang):
    if lang != "English":
        prompt = f"Translate to {lang}: {prompt}"
    result = subprocess.run(
        ["ollama", "run", "qwen3:8b"],
        input=prompt.encode(),
        stdout=subprocess.PIPE
    )
    return result.stdout.decode()

multilingual_ui = gr.Interface(
    fn=multilingual_qwen3,
    inputs=[
        gr.Textbox(label="Enter your prompt"),
        gr.Dropdown(["English", "French", "Hindi", "Chinese"], label="Target Language", value="English")
    ],
    outputs="text",
    title="Qwen3 Multilingual Translator",
    description="Use Qwen3 locally to translate prompts to different languages."
)

# %% [markdown]
# ## Launch Both Tabs in Gradio

# %%
demo = gr.TabbedInterface(
    [reasoning_ui, multilingual_ui],
    tab_names=["Reasoning Mode", "Multilingual"]
)
demo.launch(debug = True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠙ ⠙ ⠹ ⠼ ⠙ ⠙ ⠸
# Keyboard interruption in main thread... closing server.
